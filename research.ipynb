# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv("data/Fraud.csv")

df.head()
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815       170136.0       160296.36
# 1     1   PAYMENT   1864.28  C1666544295        21249.0        19384.72
# 2     1  TRANSFER    181.00  C1305486145          181.0            0.00
# 3     1  CASH_OUT    181.00   C840083671          181.0            0.00
# 4     1   PAYMENT  11668.14  C2048537720        41554.0        29885.86
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
# 2   C553264065             0.0             0.0        1               0
# 3    C38997010         21182.0             0.0        1               0
# 4  M1230701703             0.0             0.0        0               0

# %%
df["isFraud"] = df["isFraud"].astype("object")
df["isFlaggedFraud"] = df["isFlaggedFraud"].astype("object")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         object
#  10  isFlaggedFraud  object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 534.0+ MB

# %%
df.drop_duplicates(inplace=True)

# %%
df.nunique()
# Out:
# step                  743
# type                    5
# amount            5316900
# nameOrig          6353307
# oldbalanceOrg     1845844
# newbalanceOrig    2682586
# nameDest          2722362
# oldbalanceDest    3614697
# newbalanceDest    3555499
# isFraud                 2
# isFlaggedFraud          2
# dtype: int64

# %%
df.shape
# Out:
# (6362620, 11)

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.isna().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
pd.set_option("display.float_format", "{:.2f}".format)

# %%
df.describe()
# Out:
#             step      amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# count 6362620.00  6362620.00     6362620.00      6362620.00      6362620.00
# mean      243.40   179861.90      833883.10       855113.67      1100701.67
# std       142.33   603858.23     2888242.67      2924048.50      3399180.11
# min         1.00        0.00           0.00            0.00            0.00
# 25%       156.00    13389.57           0.00            0.00            0.00
# 50%       239.00    74871.94       14208.00            0.00       132705.66
# 75%       335.00   208721.48      107315.18       144258.41       943036.71
# max       743.00 92445516.64    59585040.37     49585040.37    356015889.35
#
#        newbalanceDest
# count      6362620.00
# mean       1224996.40
# std        3674128.94
# min              0.00
# 25%              0.00
# 50%         214661.44
# 75%        1111909.25
# max      356179278.92

# %%
df.describe(include="object")
# Out:
#             type     nameOrig     nameDest  isFraud  isFlaggedFraud
# count    6362620      6362620      6362620  6362620         6362620
# unique         5      6353307      2722362        2               2
# top     CASH_OUT  C1530544995  C1286084959        0               0
# freq     2237500            3          113  6354407         6362604

# %%
df["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# PAYMENT     2151495
# CASH_IN     1399284
# TRANSFER     532909
# DEBIT         41432
# Name: count, dtype: int64

# %%
df.groupby("type")["isFraud"].value_counts()
# Out:
# type      isFraud
# CASH_IN   0          1399284
# CASH_OUT  0          2233384
#           1             4116
# DEBIT     0            41432
# PAYMENT   0          2151495
# TRANSFER  0           528812
#           1             4097
# Name: count, dtype: int64

# %%
from scipy.stats import chi2_contingency

contingency_nameOrig = pd.crosstab(df["nameOrig"], df["isFraud"])
contingency_nameDest = pd.crosstab(df["nameDest"], df["isFraud"])

# %%
statistic, p_value, dof, expected = chi2_contingency(contingency_nameOrig)

if p_value <= 0.05:
    print("Reject the null hypothesis: There is a significant association between nameOrig and isFraud.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between nameOrig and isFraud.")
# Out:
# Fail to reject the null hypothesis: There is no significant association between nameOrig and isFraud.

# %%
statistic, p_value, dof, expected = chi2_contingency(contingency_nameDest)

if p_value <= 0.05:
    print("Reject the null hypothesis: There is a significant association between nameDest and isFraud.")
else:
    print("Fail to reject the null hypothesis: There is no significant association between nameDest and isFraud.")
# Out:
# Reject the null hypothesis: There is a significant association between nameDest and isFraud.

# %%
df.drop("nameOrig", axis=1, inplace=True)

# %%
nameDest_val_counts = df["nameDest"].value_counts()
frequent_vals = nameDest_val_counts[nameDest_val_counts > 1].index
df["dest_group"] = df["nameDest"].where(df["nameDest"].isin(frequent_vals), "other")
len(df["dest_group"].unique())
# Out:
# 459659

# %%
df.drop("nameDest", axis=1, inplace=True)

# %%
df.head(20)
# Out:
#     step      type    amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0      1   PAYMENT   9839.64      170136.00       160296.36            0.00
# 1      1   PAYMENT   1864.28       21249.00        19384.72            0.00
# 2      1  TRANSFER    181.00         181.00            0.00            0.00
# 3      1  CASH_OUT    181.00         181.00            0.00        21182.00
# 4      1   PAYMENT  11668.14       41554.00        29885.86            0.00
# 5      1   PAYMENT   7817.71       53860.00        46042.29            0.00
# 6      1   PAYMENT   7107.77      183195.00       176087.23            0.00
# 7      1   PAYMENT   7861.64      176087.23       168225.59            0.00
# 8      1   PAYMENT   4024.36        2671.00            0.00            0.00
# 9      1     DEBIT   5337.77       41720.00        36382.23        41898.00
# 10     1     DEBIT   9644.94        4465.00            0.00        10845.00
# 11     1   PAYMENT   3099.97       20771.00        17671.03            0.00
# 12     1   PAYMENT   2560.74        5070.00         2509.26            0.00
# 13     1   PAYMENT  11633.76       10127.00            0.00            0.00
# 14     1   PAYMENT   4098.78      503264.00       499165.22            0.00
# 15     1  CASH_OUT 229133.94       15325.00            0.00         5083.00
# 16     1   PAYMENT   1563.82         450.00            0.00            0.00
# 17     1   PAYMENT   1157.86       21156.00        19998.14            0.00
# 18     1   PAYMENT    671.64       15123.00        14451.36            0.00
# 19     1  TRANSFER 215310.30         705.00            0.00        22425.00
#
#     newbalanceDest isFraud isFlaggedFraud   dest_group
# 0             0.00       0              0        other
# 1             0.00       0              0        other
# 2             0.00       1              0   C553264065
# 3             0.00       1              0    C38997010
# 4             0.00       0              0        other
# 5             0.00       0              0        other
# 6             0.00       0              0        other
# 7             0.00       0              0        other
# 8             0.00       0              0        other
# 9         40348.79       0              0   C195600860
# 10       157982.12       0              0   C997608398
# 11            0.00       0              0        other
# 12            0.00       0              0        other
# 13            0.00       0              0        other
# 14            0.00       0              0        other
# 15        51513.44       0              0   C476402209
# 16            0.00       0              0        other
# 17            0.00       0              0        other
# 18            0.00       0              0        other
# 19            0.00       0              0  C1100439041

# %%
numerical_vals = df.select_dtypes(include=["int64", "float64"]).columns.tolist()
categorical_vals = df.select_dtypes(include=["object"]).columns.tolist()
